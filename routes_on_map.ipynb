# %% [markdown]
# <a href="https://colab.research.google.com/github/Ut-Niv/routes_on_map/blob/main/routes_on_map.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Showing routes on maps: a pragmatic approach
# Displaying Sites

# we will use the FOLIUM library to create maps and Geopy for geocoding

from typing import Tuple, List, Dict

import pandas as pd
import folium

pd.set_option('display.precision', 2) # for showing 2 decimal points

# Ceate DataFrame
df = pd.DataFrame([
     ['hotel',              48.8527, 2.3542],
     ['Sacre Coeur',        48.8867, 2.3431],
     ['Louvre',             48.8607, 2.3376],
     ['Montmartre',         48.8872, 2.3388],
     ['Port de Suffren',    48.8577, 2.2902],
     ['Arc de Triomphe',    48.8739, 2.2950],
     ['Av. Champs Élysées', 48.8710, 2.3036],
     ['Notre Dame',         48.8531, 2.3498],
     ['Tour Eiffel',        48.8585, 2.2945]
], columns = pd.Index(['Site', 'Langitude', 'Longitude'], name = 'Paris'))

# Our DataFrame
df.head()
# Out:
# Paris             Site  Langitude  Longitude
# 0                hotel      48.85       2.35
# 1          Sacre Coeur      48.89       2.34
# 2               Louvre      48.86       2.34
# 3           Montmartre      48.89       2.34
# 4      Port de Suffren      48.86       2.29

# %%
# Plot these sites on map using Felium

# create a map
avg_location = df[['Langitude', 'Longitude']].mean()
map = folium.Map(location = avg_location, zoom_start = 13)

for site in df.itertuples():
  marker = folium.Marker(location=(site.Langitude, site.Longitude), tooltip = site.Site)
  marker.add_to(map)

map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aebf0900b00aca70c45f9621a2f6966b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aebf0900b00aca70c45f9621a2f6966b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aebf0900b00aca70c45f9621a2f6966b = L.map(
#                 &quot;map_aebf0900b00aca70c45f9621a2f6966b&quot;,
#                 {
#                     center: [48.86683333333333, 2.3229777777777776],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_74aa64c8b55d5cd37543730e619df540 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_aebf0900b00aca70c45f9621a2f6966b);
#
#
#             var marker_d876fac15922375af35f6797a5bd81c7 = L.marker(
#                 [48.8527, 2.3542],
#                 {}
#             ).addTo(map_aebf0900b00aca70c45f9621a2f6966b);
#
#
#             marker_d876fac15922375af35f6797a5bd81c7.bindTooltip(
#                 `&lt;div&gt;
#                      hotel
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_bdc93c28b00099d920ec0bbe84255ceb = L.marker(
#                 [48.8867, 2.3431],
#                 {}
#             ).addTo(map_aebf0900b00aca70c45f9621a2f6966b);
#
#
#             marker_bdc93c28b00099d920ec0bbe84255ceb.bindTooltip(
#                 `&lt;div&gt;
#                      Sacre Coeur
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c01f68ecb984822e554709d6e8c1bbaf = L.marker(
#                 [48.8607, 2.3376],
#                 {}
#             ).addTo(map_aebf0900b00aca70c45f9621a2f6966b);
#
#
#             marker_c01f68ecb984822e554709d6e8c1bbaf.bindTooltip(
#                 `&lt;div&gt;
#                      Louvre
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_274b7f79f03e9730dab09a81a9c129e3 = L.marker(
#                 [48.8872, 2.3388],
#                 {}
#             ).addTo(map_aebf0900b00aca70c45f9621a2f6966b);
#
#
#             marker_274b7f79f03e9730dab09a81a9c129e3.bindTooltip(
#                 `&lt;div&gt;
#                      Montmartre
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3b27b0f2203bb8b19a544037d075e82d = L.marker(
#                 [48.8577, 2.2902],
#                 {}
#             ).addTo(map_aebf0900b00aca70c45f9621a2f6966b);
#
#
#             marker_3b27b0f2203bb8b19a544037d075e82d.bindTooltip(
#                 `&lt;div&gt;
#                      Port de Suffren
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_70425577225c63f16189800a260644ec = L.marker(
#                 [48.8739, 2.295],
#                 {}
#             ).addTo(map_aebf0900b00aca70c45f9621a2f6966b);
#
#
#             marker_70425577225c63f16189800a260644ec.bindTooltip(
#                 `&lt;div&gt;
#                      Arc de Triomphe
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3945275eec124ec562d5f25939cf801b = L.marker(
#                 [48.871, 2.3036],
#                 {}
#             ).addTo(map_aebf0900b00aca70c45f9621a2f6966b);
#
#
#             marker_3945275eec124ec562d5f25939cf801b.bindTooltip(
#                 `&lt;div&gt;
#                      Av. Champs Élysées
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_75e79e10934ec07703ca27cdd3c4caaa = L.marker(
#                 [48.8531, 2.3498],
#                 {}
#             ).addTo(map_aebf0900b00aca70c45f9621a2f6966b);
#
#
#             marker_75e79e10934ec07703ca27cdd3c4caaa.bindTooltip(
#                 `&lt;div&gt;
#                      Notre Dame
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_688ba5801519d0d4fc1e3f3943a0cf47 = L.marker(
#                 [48.8585, 2.2945],
#                 {}
#             ).addTo(map_aebf0900b00aca70c45f9621a2f6966b);
#
#
#             marker_688ba5801519d0d4fc1e3f3943a0cf47.bindTooltip(
#                 `&lt;div&gt;
#                      Tour Eiffel
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
"""# Displaying Routes

"""

df_routes = df.copy()
df_routes.index.name = 'Visit Order'
df_routes

df_route_segments = df_routes.join(
    df_routes.shift(-1),
    rsuffix = '_next'
).dropna()
df_route_segments

map_paris = folium.Map(location=avg_location, zoom_start=13)

for stop in df_route_segments.itertuples():
    # marker for current stop
    marker = folium.Marker(location=(stop.Langitude, stop.Longitude),
                           tooltip=stop.Site)
    # line for the route segment connecting current to next stop
    line = folium.PolyLine(
        locations=[(stop.Langitude, stop.Longitude),
                   (stop.Langitude_next, stop.Longitude_next)],
        tooltip=f"{stop.Site} to {stop.Site_next}",
    )
    # add elements to the map
    marker.add_to(map_paris)
    line.add_to(map_paris)

# maker for last stop wasn't added in for loop, so adding it now
folium.Marker(location=(stop.Langitude_next, stop.Longitude_next),
              tooltip=stop.Site_next).add_to(map_paris);

map_paris
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a27ebbe6f71d1eff9dbdab83996f9e26 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a27ebbe6f71d1eff9dbdab83996f9e26&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a27ebbe6f71d1eff9dbdab83996f9e26 = L.map(
#                 &quot;map_a27ebbe6f71d1eff9dbdab83996f9e26&quot;,
#                 {
#                     center: [48.86683333333333, 2.3229777777777776],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a05dfab6cdd9113a45dcfe5a67fc96fa = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a27ebbe6f71d1eff9dbdab83996f9e26);
#
#
#             var marker_9fc1b3d4802375dea0df1e38701db9ba = L.marker(
#                 [48.8527, 2.3542],
#                 {}
#             ).addTo(map_a27ebbe6f71d1eff9dbdab83996f9e26);
#
#
#             marker_9fc1b3d4802375dea0df1e38701db9ba.bindTooltip(
#                 `&lt;div&gt;
#                      hotel
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_0b98eb242c2b206ea9720e898f70d1e0 = L.polyline(
#                 [[48.8527, 2.3542], [48.8867, 2.3431]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a27ebbe6f71d1eff9dbdab83996f9e26);
#
#
#             poly_line_0b98eb242c2b206ea9720e898f70d1e0.bindTooltip(
#                 `&lt;div&gt;
#                      hotel to Sacre Coeur
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5adafee0e041d1deafad0b3850986826 = L.marker(
#                 [48.8867, 2.3431],
#                 {}
#             ).addTo(map_a27ebbe6f71d1eff9dbdab83996f9e26);
#
#
#             marker_5adafee0e041d1deafad0b3850986826.bindTooltip(
#                 `&lt;div&gt;
#                      Sacre Coeur
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_02dec4c8838f374ff575c46dd355ab3e = L.polyline(
#                 [[48.8867, 2.3431], [48.8607, 2.3376]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a27ebbe6f71d1eff9dbdab83996f9e26);
#
#
#             poly_line_02dec4c8838f374ff575c46dd355ab3e.bindTooltip(
#                 `&lt;div&gt;
#                      Sacre Coeur to Louvre
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_8975fc41b19c4517aea5494cc70f9518 = L.marker(
#                 [48.8607, 2.3376],
#                 {}
#             ).addTo(map_a27ebbe6f71d1eff9dbdab83996f9e26);
#
#
#             marker_8975fc41b19c4517aea5494cc70f9518.bindTooltip(
#                 `&lt;div&gt;
#                      Louvre
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_e1c42ce9b002e91bcc9d112596e53993 = L.polyline(
#                 [[48.8607, 2.3376], [48.8872, 2.3388]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_a27ebbe6f71d1eff9dbdab83996f9e26);
#
#
#             poly_line_e1c42ce9b002e91bcc9d112596e53993.bindTooltip(
#                 `&lt;div&gt;
#                      Louvre to Montmartre
#                  &lt;/div&gt;`,

# %%
"""# Enriching the map with the interactive information"""

# use of folium.Icon on each marker for distinct icon

map = folium.Map(location=avg_location, zoom_start = 13)
for stop in df_route_segments.itertuples():
  initial_stop = stop.Index == 0
  icon = folium.Icon(icon='home' if initial_stop else 'info-sign',
                     color='cadetblue' if initial_stop else 'red')
  marker = folium.Marker(location = (stop.Langitude, stop.Longitude),
                                     icon = icon, tooltip = stop.Site)
  line = folium.PolyLine(locations = [(stop.Langitude, stop.Longitude),
                                     (stop.Langitude_next, stop.Longitude_next)
                                    ],
                         tooltip = f"{stop.Site} to {stop.Site_next}",
                        )
  marker.add_to(map)
  line.add_to(map)


  folium.Marker(location=(stop.Langitude_next, stop.Longitude_next),
                tooltip = stop.Site_next,
                icon = folium.Icon(icon = 'info-sign', colot='red')
              ).add_to(map);
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c48b0c1fb0b5748b30d00bbf561c17be {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c48b0c1fb0b5748b30d00bbf561c17be&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c48b0c1fb0b5748b30d00bbf561c17be = L.map(
#                 &quot;map_c48b0c1fb0b5748b30d00bbf561c17be&quot;,
#                 {
#                     center: [48.86683333333333, 2.3229777777777776],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eabb2f8758f69b2a72a44f5d56cf1da9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c48b0c1fb0b5748b30d00bbf561c17be);
#
#
#             var marker_3c5b3033a2c1ff14e0fd3f6800784691 = L.marker(
#                 [48.8527, 2.3542],
#                 {}
#             ).addTo(map_c48b0c1fb0b5748b30d00bbf561c17be);
#
#
#             var icon_17d315e53dc47dba28d9d48168505f83 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3c5b3033a2c1ff14e0fd3f6800784691.setIcon(icon_17d315e53dc47dba28d9d48168505f83);
#
#
#             marker_3c5b3033a2c1ff14e0fd3f6800784691.bindTooltip(
#                 `&lt;div&gt;
#                      hotel
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_3c3bfed48fd7bd46b86f6ada47f34319 = L.polyline(
#                 [[48.8527, 2.3542], [48.8867, 2.3431]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_c48b0c1fb0b5748b30d00bbf561c17be);
#
#
#             poly_line_3c3bfed48fd7bd46b86f6ada47f34319.bindTooltip(
#                 `&lt;div&gt;
#                      hotel to Sacre Coeur
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2ace35ffc20fe7ca12e2e3cd1a3faf10 = L.marker(
#                 [48.8867, 2.3431],
#                 {}
#             ).addTo(map_c48b0c1fb0b5748b30d00bbf561c17be);
#
#
#             var icon_217200fdcb6338858df32da554795a89 = L.AwesomeMarkers.icon(
#                 {&quot;colot&quot;: &quot;red&quot;, &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_2ace35ffc20fe7ca12e2e3cd1a3faf10.setIcon(icon_217200fdcb6338858df32da554795a89);
#
#
#             marker_2ace35ffc20fe7ca12e2e3cd1a3faf10.bindTooltip(
#                 `&lt;div&gt;
#                      Sacre Coeur
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5489633013832605429bc2b403b3dacc = L.marker(
#                 [48.8867, 2.3431],
#                 {}
#             ).addTo(map_c48b0c1fb0b5748b30d00bbf561c17be);
#
#
#             var icon_c34b0865a25d786d751e4e8c4feee024 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_5489633013832605429bc2b403b3dacc.setIcon(icon_c34b0865a25d786d751e4e8c4feee024);
#
#
#             marker_5489633013832605429bc2b403b3dacc.bindTooltip(
#                 `&lt;div&gt;
#                      Sacre Coeur
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_169650426954f7c9bd830ff01c2c1c0b = L.polyline(
#                 [[48.8867, 2.3431], [48.8607, 2.3376]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &qu

# %%
"""# add distances between stops and the visit order of each stop."""

from geopy.distance import geodesic

_Location = Tuple[float, float]

def ellipsoidal_distance(point1: _Location, point2: _Location) -> float:
  # Calculate ellipsodial distance between point1 and point2
  return geodesic(point1, point2).meters

df_route_segments['distance_seg'] = df_route_segments.apply(
    lambda seg: ellipsoidal_distance((seg.Langitude, seg.Longitude),
                                     (seg.Langitude_next, seg.Longitude_next))
    ,axis = 1
)

# Distance between points distance_seg
df_route_segments
# Out:
# Paris                      Site  Langitude  Longitude           Site_next  \
# Visit Order
# 0                         hotel      48.85       2.35         Sacre Coeur
# 1                   Sacre Coeur      48.89       2.34              Louvre
# 2                        Louvre      48.86       2.34          Montmartre
# 3                    Montmartre      48.89       2.34     Port de Suffren
# 4               Port de Suffren      48.86       2.29     Arc de Triomphe
# 5               Arc de Triomphe      48.87       2.29  Av. Champs Élysées
# 6            Av. Champs Élysées      48.87       2.30          Notre Dame
# 7                    Notre Dame      48.85       2.35         Tour Eiffel
#
# Paris        Langitude_next  Longitude_next  distance_seg
# Visit Order
# 0                     48.89            2.34       3867.74
# 1                     48.86            2.34       2919.40
# 2                     48.89            2.34       2948.31
# 3                     48.86            2.29       4844.92
# 4                     48.87            2.29       1835.65
# 5                     48.87            2.30        708.53
# 6                     48.85            2.35       3931.12
# 7                     48.86            2.29       4102.26

# %%
# Let's add stop numbers to the marker too
map = folium.Map(location=avg_location, zoom_start = 13)

for stop in df_route_segments.itertuples():
  initial_stop = stop.Index == 0
  icon = folium.Icon(icon='home' if initial_stop else 'info-sign',
                     color='cadetblue' if initial_stop else 'red')
  marker = folium.Marker(location = (stop.Langitude, stop.Longitude),
                                     icon = icon,
                        #  Display the name and stop number at each site's maker
                        tooltip = f"<b>Name</b>:{stop.Site} <br>" +
                                  f"<b>Stop Number</b>: {stop.Index}<br>"
                        )
  line = folium.PolyLine(locations = [(stop.Langitude, stop.Longitude),
                                     (stop.Langitude_next, stop.Longitude_next)
                                    ],
                                   tooltip=f"<b>From</b>: {stop.Site} <br>"
                                        + f"<b>To</b>: {stop.Site_next} <br>"
                                + f"<b>Distance</b>: {stop.distance_seg:.0f} m",
                         )

  marker.add_to(map)
  line.add_to(map)


  folium.Marker(location=(stop.Langitude_next, stop.Longitude_next),
                tooltip = f"<b>Name</b>: {stop.Site_next}<br>" +
                          f"<b>Stop number</b>: {stop.Index + 1} <br>",
                icon = folium.Icon(icon = 'info-sign', colot='red')
              ).add_to(map);
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_58d52fc4c22c28daf87197c6e603437a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_58d52fc4c22c28daf87197c6e603437a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_58d52fc4c22c28daf87197c6e603437a = L.map(
#                 &quot;map_58d52fc4c22c28daf87197c6e603437a&quot;,
#                 {
#                     center: [48.86683333333333, 2.3229777777777776],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9ed470f215ceeffb7cf5769fe6ffcfc3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_58d52fc4c22c28daf87197c6e603437a);
#
#
#             var marker_d9a800c4e5f80c2fd4ddd61fe00b5a74 = L.marker(
#                 [48.8527, 2.3542],
#                 {}
#             ).addTo(map_58d52fc4c22c28daf87197c6e603437a);
#
#
#             var icon_1d9ab8ebe75fc66b7939a4d99078ff19 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d9a800c4e5f80c2fd4ddd61fe00b5a74.setIcon(icon_1d9ab8ebe75fc66b7939a4d99078ff19);
#
#
#             marker_d9a800c4e5f80c2fd4ddd61fe00b5a74.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Name&lt;/b&gt;:hotel &lt;br&gt;&lt;b&gt;Stop Number&lt;/b&gt;: 0&lt;br&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_3e1a53f8551a3dda69a522947ec5a284 = L.polyline(
#                 [[48.8527, 2.3542], [48.8867, 2.3431]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_58d52fc4c22c28daf87197c6e603437a);
#
#
#             poly_line_3e1a53f8551a3dda69a522947ec5a284.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;From&lt;/b&gt;: hotel &lt;br&gt;&lt;b&gt;To&lt;/b&gt;: Sacre Coeur &lt;br&gt;&lt;b&gt;Distance&lt;/b&gt;: 3868 m
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_ccc9c990cca1d1f4421c3cb54c5f9d96 = L.marker(
#                 [48.8867, 2.3431],
#                 {}
#             ).addTo(map_58d52fc4c22c28daf87197c6e603437a);
#
#
#             var icon_a7f68215e58bdb9242106ad970120197 = L.AwesomeMarkers.icon(
#                 {&quot;colot&quot;: &quot;red&quot;, &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ccc9c990cca1d1f4421c3cb54c5f9d96.setIcon(icon_a7f68215e58bdb9242106ad970120197);
#
#
#             marker_ccc9c990cca1d1f4421c3cb54c5f9d96.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Name&lt;/b&gt;: Sacre Coeur&lt;br&gt;&lt;b&gt;Stop number&lt;/b&gt;: 1 &lt;br&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e5aa89cf4a29b2d393be733676789ce9 = L.marker(
#                 [48.8867, 2.3431],
#                 {}
#             ).addTo(map_58d52fc4c22c28daf87197c6e603437a);
#
#
#             var icon_fb374ec34d75518ae6b25f5e0e1a8ed2 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e5aa89cf4a29b2d393be733676789ce9.setIcon(icon_fb374ec34d75518ae6b25f5e0e1a8ed2);
#
#
#             marker_e5aa89cf4a29b2d393be733676789ce9.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Name&lt;/b&gt;:Sacre Coeur &lt;br&gt;&lt;b&gt;Stop Number&lt;/b&gt;: 1&lt;br&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_8fd2ed4c28e120b4bfceb84455b6db6d = L.polyline(
#                 [[48.8867, 2.3431], [48.8607, 2.3376]],

# %%
# bit of HTML to render the “hover text” displayed on markers and lines more
# nicely.

def _make_routes_segments(df_route: pd.DataFrame) -> pd.DataFrame:
  df_route_segments = df_route.join(
      df_route.shift(-1),
      rsuffix = '_next').dropna()
  df_route_segments['distance_seg'] = df_route_segments.apply(
      lambda stop: ellipsoidal_distance(
          (stop.Langitude, stop.Longitude),
            (stop.Langitude_next, stop.Longitude_next)
        ), axis=1
      )
  return df_route_segments

def plot_route_on_map(df_route: pd.DataFrame) -> folium.Map:
  df_route_segments = _make_routes_segments(df_route)
  agv_location = df_route[['Langitude', 'Longitude']].mean()
  map_route = folium.Map(location = avg_location, zoom_start = 13)

  for stop in df_route_segments.itertuples():
    initial_stop = stop.Index == 0
    # marker for current stop
    icon = folium.Icon(icon='home' if initial_stop else 'info-sign',
                        color='cadetblue' if initial_stop else 'red')
    marker = folium.Marker(
        location=(stop.Langitude, stop.Longitude),
        icon=icon,
        tooltip=f"<b>Name</b>: {stop.Site} <br>" \
              + f"<b>Stop number</b>: {stop.Index} <br>"
    )
    # line for the route segment connecting current to next stop
    line = folium.PolyLine(
        locations=[(stop.Langitude, stop.Longitude),
                    (stop.Langitude_next, stop.Longitude_next)],
        # add to each line its start, end, and distance
        tooltip=f"<b>From</b>: {stop.Site} <br>" \
              + f"<b>To</b>: {stop.Site_next} <br>" \
              + f"<b>Distance</b>: {stop.distance_seg:.0f} m",
    )
    marker.add_to(map_route)
    line.add_to(map_route)

  first_stop = df_route_closed.iloc[0][['Site', 'Langitude', 'Longitude']]
  last_stop = df_route_closed.iloc[-1][['Site', 'Langitude', 'Longitude']]
  is_closed_tour = (first_stop == last_stop).all()

  if not is_closed_tour:
    folium.Marker(location = (stop.Langitude_next, stop.Longitude_next),
                  tooltip = f"<b>Name</b>: {stop.Site_next} <br>" +
                            f"<b>Stop number</b>: {stop.Index + 1} <br>",
                  icon = folium.Icon(icon = 'info-sign', color = 'red')
                ).add_to(map_route)
  return map_route

# %%
"""# Dealing with closed routes, a.k.a. tours"""

df_route_closed = pd.concat(
    [df_routes, df_routes.head(1)], ignore_index = True
)
df_route_closed.index.name = df_routes.index.name
df_route_closed

plot_route_on_map(df_route_closed)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0e484ab1ac41d445ebceb2a91a67cd3a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0e484ab1ac41d445ebceb2a91a67cd3a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0e484ab1ac41d445ebceb2a91a67cd3a = L.map(
#                 &quot;map_0e484ab1ac41d445ebceb2a91a67cd3a&quot;,
#                 {
#                     center: [48.86683333333333, 2.3229777777777776],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7c8dcc30e294b153eff0abeffa0c8351 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0e484ab1ac41d445ebceb2a91a67cd3a);
#
#
#             var marker_60c29cfbc2701f58650b50b9b199cc9b = L.marker(
#                 [48.8527, 2.3542],
#                 {}
#             ).addTo(map_0e484ab1ac41d445ebceb2a91a67cd3a);
#
#
#             var icon_52300fb688e3fb16e79c7ee2f1b40f1d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;home&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;cadetblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_60c29cfbc2701f58650b50b9b199cc9b.setIcon(icon_52300fb688e3fb16e79c7ee2f1b40f1d);
#
#
#             marker_60c29cfbc2701f58650b50b9b199cc9b.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Name&lt;/b&gt;: hotel &lt;br&gt;&lt;b&gt;Stop number&lt;/b&gt;: 0 &lt;br&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_89533cca3c165ccb0dfecf432f6fb044 = L.polyline(
#                 [[48.8527, 2.3542], [48.8867, 2.3431]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0e484ab1ac41d445ebceb2a91a67cd3a);
#
#
#             poly_line_89533cca3c165ccb0dfecf432f6fb044.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;From&lt;/b&gt;: hotel &lt;br&gt;&lt;b&gt;To&lt;/b&gt;: Sacre Coeur &lt;br&gt;&lt;b&gt;Distance&lt;/b&gt;: 3868 m
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_3bc7200c30a16399fed9bce54afe4d13 = L.marker(
#                 [48.8867, 2.3431],
#                 {}
#             ).addTo(map_0e484ab1ac41d445ebceb2a91a67cd3a);
#
#
#             var icon_d84de827044bed1e676861051f9d3c9a = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3bc7200c30a16399fed9bce54afe4d13.setIcon(icon_d84de827044bed1e676861051f9d3c9a);
#
#
#             marker_3bc7200c30a16399fed9bce54afe4d13.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;Name&lt;/b&gt;: Sacre Coeur &lt;br&gt;&lt;b&gt;Stop number&lt;/b&gt;: 1 &lt;br&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var poly_line_e9e8e2a6b02fccec85b8439f683dcf5f = L.polyline(
#                 [[48.8867, 2.3431], [48.8607, 2.3376]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0e484ab1ac41d445ebceb2a91a67cd3a);
#
#
#             poly_line_e9e8e2a6b02fccec85b8439f683dcf5f.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;b&gt;From&lt;/b&gt;: Sacre Coeur &lt;br&gt;&lt;b&gt;To&lt;/b&gt;: Louvre &lt;br&gt;&lt;b&gt;Distance&lt;/b&gt;: 2919 m
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cf5332c898a2dd870450da015d646a68 =
